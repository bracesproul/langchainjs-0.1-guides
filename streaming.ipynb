// %% [markdown]
// # Streaming
// This notebook covers functionality related to streaming.
//
// For more information, see:
//
// - [Streaming with LCEL](https://js.langchain.com/docs/expression_language/interface#stream)
// - [Streaming for Agents](https://js.langchain.com/docs/modules/agents/how_to/streaming)
//
// ## Basic Streaming

// %%
import { ChatOpenAI } from "@langchain/openai";
import { ChatPromptTemplate } from "@langchain/core/prompts";
import { StringOutputParser } from "@langchain/core/output_parsers";

// %%
const prompt = ChatPromptTemplate.fromTemplate("Tell me a joke about {topic}");
const model = new ChatOpenAI({
  modelName: "gpt-3.5-turbo",
  temperature: 0,
});
const parser = new StringOutputParser();
const chain = prompt.pipe(model).pipe(parser);

// %%
for await (const step of await chain.stream({
  topic: "bears",
})) {
  console.log(step);
}
// Out:
// Why
//  don
// 't
//  bears
//  wear
//  shoes
// ?
//
//
// Because
//  they
//  have
//  bear
//  feet
// !

// %% [markdown]
// ## Streaming with RunnableParallel

// %%
import { RunnableParallel } from "@langchain/core/runnables";

const prompt = ChatPromptTemplate.fromTemplate("Tell me a joke about {topic}");
const model = new ChatOpenAI({
  modelName: "gpt-3.5-turbo",
  temperature: 0,
});
const parser = new StringOutputParser();
const chain1 = prompt.pipe(model).pipe(parser);

// %%
const prompt = ChatPromptTemplate.fromTemplate("Write me a poem about {topic}");
const model = new ChatOpenAI({
  modelName: "gpt-3.5-turbo",
  temperature: 0,
});
const parser = new StringOutputParser();
const chain2 = prompt.pipe(model).pipe(parser);

// %%
const parallelChain = new RunnableParallel({
  steps: {
    joke: chain1,
    poem: chain2
  }
});

for await (const step of await parallelChain.stream({
  topic: "bears",
})) {
  console.log(step);
}
// Out:
// { poem: "" }
// { poem: "In" }
// { poem: " the" }
// { poem: " heart" }
// { poem: " of" }
// { poem: " the" }
// { poem: " wild" }
// { poem: "," }
// { poem: " where" }
// { poem: " nature" }
// { joke: "" }
// { joke: "Why" }
// { joke: " don" }
// { joke: "'t" }
// { joke: " bears" }
// { joke: " wear" }
// { joke: " shoes" }
// { poem: " thr" }
// { poem: "ives" }
// { poem: ",\n" }
// { poem: "Ro" }
// { poem: "ams" }
// { poem: " a" }
// { joke: "?\n\n" }
// { joke: "Because" }
// { joke: " they" }
// { joke: " have" }
// { joke: " bear" }
// { joke: " feet" }
// { joke: "!" }
// { joke: "" }
// { poem: " majestic" }
// { poem: " creature" }
// { poem: "," }
// { poem: " with" }
// { poem: " strength" }
// { poem: " and" }
// { poem: " drive" }
// { poem: ".\n" }
// { poem: "With" }
// { poem: " fur" }
// { poem: " of" }
// { poem: " gold" }
// { poem: "," }
// { poem: " or" }
// { poem: " black" }
// { poem: " as" }
// { poem: " night" }
// { poem: ",\n" }
// { poem: "B" }
// { poem: "ears" }
// { poem: " command" }
// { poem: " the" }
// { poem: " forest" }
// { poem: "," }
// { poem: " their" }
// { poem: " realm" }
// { poem: " of" }
// { poem: " might" }
// { poem: ".\n\n" }
// { poem: "In" }
// { poem: " the" }
// { poem: " depths" }
// { poem: " of" }
// { poem: " the" }
// { poem: " woods" }
// { poem: "," }
// { poem: " where" }
// { poem: " secrets" }
// { poem: " hide" }
// { poem: ",\n" }
// { poem: "A" }
// { poem: " bear" }
// { poem: "'s" }
// { poem: " presence" }
// { poem: " is" }
// { poem: " felt" }
// { poem: "," }
// { poem: " a" }
// { poem: " force" }
// { poem: " to" }
// { poem: " abide" }
// { poem: ".\n" }
// { poem: "With" }
// { poem: " p" }
// { poem: "aws" }
// { poem: " like" }
// { poem: " thunder" }
// { poem: "," }
// { poem: " they" }
// { poem: " tread" }
// { poem: " with" }
// { poem: " grace" }
// { poem: ",\n" }
// { poem: "Navig" }
// { poem: "ating" }
// { poem: " the" }
// { poem: " wilderness" }
// { poem: "," }
// { poem: " leaving" }
// { poem: " no" }
// { poem: " trace" }
// { poem: ".\n\n" }
// { poem: "Their" }
// { poem: " eyes" }
// { poem: "," }
// { poem: " like" }
// { poem: " amber" }
// { poem: "," }
// { poem: " hold" }
// { poem: " ancient" }
// { poem: " tales" }
// { poem: ",\n" }
// { poem: "Of" }
// { poem: " wisdom" }
// { poem: " and" }
// { poem: " courage" }
// { poem: "," }
// { poem: " as" }
// { poem: " the" }
// { poem: " wind" }
// { poem: " w" }
// { poem: "ails" }
// { poem: ".\n" }
// { poem: "They" }
// { poem: " roam" }
// { poem: " through" }
// { poem: " the" }
// { poem: " seasons" }
// { poem: "," }
// { poem: " in" }
// { poem: " search" }
// { poem: " of" }
// { poem: " prey" }
// { poem: ",\n" }
// { poem: "Yet" }
// { poem: "," }
// { poem: " gentle" }
// { poem: " they" }
// { poem: " are" }
// { poem: "," }
// { poem: " in" }
// { poem: " their" }
// { poem: " own" }
// { poem: " special" }
// { poem: " way" }
// { poem: ".\n\n" }
// { poem: "In" }
// { poem: " winter" }
// { poem: "'s" }
// { poem: " embrace" }
// { poem: "," }
// { poem: " they" }
// { poem: " find" }
// { poem: " their" }
// { poem: " den" }
// { poem: ",\n" }
// { poem: "A" }
// { poem: " sanctuary" }
// { poem: " of" }
// { poem: " warmth" }
// { poem: "," }
// { poem: " where" }
// { poem: " dreams" }
// { poem: " begin" }
// { poem: ".\n" }
// { poem: "H" }
// { poem: "ibern" }
// { poem: "ating" }
// { poem: " peacefully" }
// { poem: "," }
// { poem: " in" }
// { poem: " sl" }
// { poem: "umber" }
// { poem: "'s" }
// { poem: " embrace" }
// { poem: ",\n" }
// { poem: "Await" }
// { poem: "ing" }
// { poem: " the" }
// { poem: " dawn" }
// { poem: "," }
// { poem: " with" }
// { poem: " a" }
// { poem: " patient" }
// { poem: " grace" }
// { poem: ".\n\n" }
// { poem: "From" }
// { poem: " c" }
// { poem: "ubs" }
// { poem: " to" }
// { poem: " adults" }
// { poem: "," }
// { poem: " they" }
// { poem: " learn" }
// { poem: " life" }
// { poem: "'s" }
// { poem: " dance" }
// { poem: ",\n" }
// { poem: "Guid" }
// { poem: "ed" }
// { poem: " by" }
// { poem: " mothers" }
// { poem: "," }
// { poem: " who" }
// { poem: " offer" }
// { poem: " a" }
// { poem: " chance" }
// { poem: ",\n" }
// { poem: "To" }
// { poem: " grow" }
// { poem: " and" }
// { poem: " explore" }
// { poem: "," }
// { poem: " in" }
// { poem: " this" }
// { poem: " vast" }
// { poem: " domain" }
// { poem: ",\n" }
// { poem: "To" }
// { poem: " become" }
// { poem: " the" }
// { poem: " guardians" }
// { poem: "," }
// { poem: " who" }
// { poem: " shall" }
// { poem: " remain" }
// { poem: ".\n\n" }
// { poem: "B" }
// { poem: "ears" }
// { poem: "," }
// { poem: " the" }
// { poem: " guardians" }
// { poem: " of" }
// { poem: " the" }
// { poem: " wild" }
// { poem: " and" }
// { poem: " free" }
// { poem: ",\n" }
// { poem: "Symbol" }
// { poem: "ize" }
// { poem: " strength" }
// { poem: "," }
// { poem: " in" }
// { poem: " their" }
// { poem: " every" }
// { poem: " decree" }
// { poem: ".\n" }
// { poem: "They" }
// { poem: " teach" }
// { poem: " us" }
// { poem: " to" }
// { poem: " be" }
// { poem: " resilient" }
// { poem: "," }
// { poem: " to" }
// { poem: " stand" }
// { poem: " tall" }
// { poem: ",\n" }
// { poem: "To" }
// { poem: " protect" }
// { poem: " our" }
// { poem: " world" }
// { poem: "," }
// { poem: " for" }
// { poem: " one" }
// { poem: " and" }
// { poem: " all" }
// { poem: ".\n\n" }
// { poem: "So" }
// { poem: " let" }
// { poem: " us" }
// { poem: " honor" }
// { poem: " these" }
// { poem: " creatures" }
// { poem: "," }
// { poem: " so" }
// { poem: " rare" }
// { poem: ",\n" }
// { poem: "With" }
// { poem: " reverence" }
// { poem: " and" }
// { poem: " awe" }
// { poem: "," }
// { poem: " let" }
// { poem: "'s" }
// { poem: " show" }
// { poem: " we" }
// { poem: " care" }
// { poem: ".\n" }
// { poem: "For" }
// { poem: " in" }
// { poem: " their" }
// { poem: " existence" }
// { poem: "," }
// { poem: " we" }
// { poem: " find" }
// { poem: " a" }
// { poem: " reflection" }
// { poem: ",\n" }
// { poem: "Of" }
// { poem: " the" }
// { poem: " beauty" }
// { poem: " and" }
// { poem: " power" }
// { poem: "," }
// { poem: " in" }
// { poem: " nature" }
// { poem: "'s" }
// { poem: " perfection" }
// { poem: "." }
// { poem: "" }

// %%
let result = {};
for await (const step of await parallelChain.stream({
  topic: "bears",
})) {
  for (const [k, v] of Object.entries(step)) {
    result[k] = result[k] || "";
    result[k] += v;
  }
  console.log(result);
}
// Out:
// { poem: "" }
// { poem: "", joke: "" }
// { poem: "", joke: "Why" }
// { poem: "", joke: "Why don" }
// { poem: "", joke: "Why don't" }
// { poem: "In", joke: "Why don't" }
// { poem: "In", joke: "Why don't bears" }
// { poem: "In the", joke: "Why don't bears" }
// { poem: "In the", joke: "Why don't bears wear" }
// { poem: "In the heart", joke: "Why don't bears wear" }
// { poem: "In the heart", joke: "Why don't bears wear shoes" }
// { poem: "In the heart of", joke: "Why don't bears wear shoes" }
// { poem: "In the heart of the", joke: "Why don't bears wear shoes" }
// {
//   poem: "In the heart of the wild",
//   joke: "Why don't bears wear shoes"
// }
// {
//   poem: "In the heart of the wild,",
//   joke: "Why don't bears wear shoes"
// }
// {
//   poem: "In the heart of the wild, where",
//   joke: "Why don't bears wear shoes"
// }
// {
//   poem: "In the heart of the wild, where nature",
//   joke: "Why don't bears wear shoes"
// }
// {
//   poem: "In the heart of the wild, where nature thr",
//   joke: "Why don't bears wear shoes"
// }
// {
//   poem: "In the heart of the wild, where nature thrives",
//   joke: "Why don't bears wear shoes"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n",
//   joke: "Why don't bears wear shoes"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\nRo",
//   joke: "Why don't bears wear shoes"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\nRo",
//   joke: "Why don't bears wear shoes?\n\n"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\nRo",
//   joke: "Why don't bears wear shoes?\n\nBecause"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\nRo",
//   joke: "Why don't bears wear shoes?\n\nBecause they"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\nRoams",
//   joke: "Why don't bears wear shoes?\n\nBecause they"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\nRoams a",
//   joke: "Why don't bears wear shoes?\n\nBecause they"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\nRoams a majestic",
//   joke: "Why don't bears wear shoes?\n\nBecause they"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\nRoams a majestic",
//   joke: "Why don't bears wear shoes?\n\nBecause they have"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\nRoams a majestic",
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\nRoams a majestic",
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\nRoams a majestic",
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\nRoams a majestic",
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\nRoams a majestic creature",
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\nRoams a majestic creature,",
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with",
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength",
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and",
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive",
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n",
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 4 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 8 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 11 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 16 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 17 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 20 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 26 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 29 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 35 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 37 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 38 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 42 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 50 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 54 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 61 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 62 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 68 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 74 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 77 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 83 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 86 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 88 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 92 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 99 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 102 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 106 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 112 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 113 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 119 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 127 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 132 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 134 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 135 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 140 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 142 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 151 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 154 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 159 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 160 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 162 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 168 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 171 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 177 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 179 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 183 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 185 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 188 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 193 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 201 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 202 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 207 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 213 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 218 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 224 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 226 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 231 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 236 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 240 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 251 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 252 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 260 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 263 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 269 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 272 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 277 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 282 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 283 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 288 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 294 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 295 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 300 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 308 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 314 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 316 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 318 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 325 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 329 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 337 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 338 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 341 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 345 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 350 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 352 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 356 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 358 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 362 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 367 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 375 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 379 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 387 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 388 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 391 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 398 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 401 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 406 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 408 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 411 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 412 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 419 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 424 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 428 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 429 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 432 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 438 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 442 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 450 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 454 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 457 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 459 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 466 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 468 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 476 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 477 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 482 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 487 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 493 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 497 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 499 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 500 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 510 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 513 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 520 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 521 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 527 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 534 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 540 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 542 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 543 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 548 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 553 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 564 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 565 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 568 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 571 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 576 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 578 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 586 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 588 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 593 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 596 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 600 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 605 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 606 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 611 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 613 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 621 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 627 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 630 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 634 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 636 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 639 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 642 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 649 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 650 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 655 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 661 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 666 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 668 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 674 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 676 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 680 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 682 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 685 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 693 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 694 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 698 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 704 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 706 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 713 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 715 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 717 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 722 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 726 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 734 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 735 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 738 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 743 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 748 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 755 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 757 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 759 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 766 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 770 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 780 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 781 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 785 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 791 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 798 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 801 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 802 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 806 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 807 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 811 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 821 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 824 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 828 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 833 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 837 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 842 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 844 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
// ...
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 853 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 862 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 863 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 866 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 872 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 878 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 885 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 887 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 891 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 897 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 900 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 903 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 906 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 916 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 917 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 920 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 926 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 931 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 933 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 935 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 943 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 947 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 953 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 954 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 958 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 962 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 966 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 970 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 973 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 975 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 979 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 982 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 988 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 994 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1004 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1005 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1008 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1013 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1015 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1019 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1029 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1033 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1037 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1038 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1042 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1044 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1049 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1052 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1057 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1059 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1062 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1065 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1071 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1081 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1082 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1085 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1090 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1092 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1103 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1105 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1107 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1111 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1118 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1122 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1128 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1129 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1132 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1139 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1141 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1152 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1153 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }
// {
//   poem: "In the heart of the wild, where nature thrives,\n" +
//     "Roams a majestic creature, with strength and drive.\n"... 1153 more characters,
//   joke: "Why don't bears wear shoes?\n\nBecause they have bear feet!"
// }

// %% [markdown]
// ## Stream Log

// %%
import { TavilySearchAPIRetriever } from "@langchain/community/retrievers/tavily_search_api";
import { formatDocumentsAsString } from "langchain/util/document";
import { RunnablePassthrough } from "@langchain/core/runnables";

const retriever = new TavilySearchAPIRetriever();

const prompt = ChatPromptTemplate.fromTemplate(`Answer the question based only on the context provided:

Context: {context}

Question: {question}`);

const question = "what is langsmith"

const chain = prompt.pipe(model).pipe(parser);

const retrievalChain = RunnablePassthrough.assign({
  context: async (i: { question: string }) =>
  formatDocumentsAsString(await retriever.withConfig({ runName: "Docs" }).invoke(question))
}).withConfig({ runName: "passthrough" }).pipe(chain);

for await (const step of await retrievalChain.streamLog({
  question,
})) {
  console.log(step);
}
// Out:
// RunLogPatch {
//   ops: [
//     {
//       op: "replace",
//       path: "",
//       value: {
//         id: "3eab58e9-e4e7-446b-b4b0-bc14ae4f3ca9",
//         streamed_output: [],
//         final_output: undefined,
//         logs: {}
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/passthrough",
//       value: {
//         id: "7e1c773d-743c-43b7-98cd-28f6e2ecd094",
//         name: "passthrough",
//         type: "chain",
//         tags: [ "seq:step:1" ],
//         metadata: {},
//         start_time: "2024-01-08T20:55:49.927Z",
//         streamed_output_str: [],
//         final_output: undefined,
//         end_time: undefined
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/RunnableMap",
//       value: {
//         id: "9bef378d-b676-4043-a568-19604435e1eb",
//         name: "RunnableMap",
//         type: "chain",
//         tags: [],
//         metadata: {},
//         start_time: "2024-01-08T20:55:50.050Z",
//         streamed_output_str: [],
//         final_output: undefined,
//         end_time: undefined
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/RunnableLambda",
//       value: {
//         id: "f860989c-0032-4cbd-bd1b-afa68384abb5",
//         name: "RunnableLambda",
//         type: "chain",
//         tags: [ "map:key:context" ],
//         metadata: {},
//         start_time: "2024-01-08T20:55:50.164Z",
//         streamed_output_str: [],
//         final_output: undefined,
//         end_time: undefined
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/RunnableLambda/final_output",
//       value: {
//         output: "We often use this for a couple of reasons:\n" +
//           "To assess subjective qualities that automatic evaluators "... 11370 more characters
//       }
//     },
//     {
//       op: "add",
//       path: "/logs/RunnableLambda/end_time",
//       value: "2024-01-08T20:55:51.848Z"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/RunnableMap/final_output",
//       value: {
//         context: "We often use this for a couple of reasons:\n" +
//           "To assess subjective qualities that automatic evaluators "... 11370 more characters
//       }
//     },
//     {
//       op: "add",
//       path: "/logs/RunnableMap/end_time",
//       value: "2024-01-08T20:55:51.996Z"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/passthrough/final_output",
//       value: {
//         question: "what is langsmith",
//         context: "We often use this for a couple of reasons:\n" +
//           "To assess subjective qualities that automatic evaluators "... 11370 more characters
//       }
//     },
//     {
//       op: "add",
//       path: "/logs/passthrough/end_time",
//       value: "2024-01-08T20:55:52.160Z"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/RunnableSequence",
//       value: {
//         id: "9a90edc1-2a18-4fc6-af44-f4fda5e344e3",
//         name: "RunnableSequence",
//         type: "chain",
//         tags: [ "seq:step:2" ],
//         metadata: {},
//         start_time: "2024-01-08T20:55:52.274Z",
//         streamed_output_str: [],
//         final_output: undefined,
//         end_time: undefined
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatPromptTemplate",
//       value: {
//         id: "c7820c66-771d-4fce-9052-541b0cb062f5",
//         name: "ChatPromptTemplate",
//         type: "prompt",
//         tags: [ "seq:step:1" ],
//         metadata: {},
//         start_time: "2024-01-08T20:55:52.443Z",
//         streamed_output_str: [],
//         final_output: undefined,
//         end_time: undefined
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatPromptTemplate/final_output",
//       value: ChatPromptValue {
//         lc_serializable: true,
//         lc_kwargs: { messages: [Array] },
//         lc_namespace: [ "langchain_core", "prompt_values" ],
//         messages: [ [HumanMessage] ]
//       }
//     },
//     {
//       op: "add",
//       path: "/logs/ChatPromptTemplate/end_time",
//       value: "2024-01-08T20:55:52.556Z"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI",
//       value: {
//         id: "5568aec2-187a-423e-8836-992c3c53a97e",
//         name: "ChatOpenAI",
//         type: "llm",
//         tags: [ "seq:step:2" ],
//         metadata: {},
//         start_time: "2024-01-08T20:55:52.679Z",
//         streamed_output_str: [],
//         final_output: undefined,
//         end_time: undefined
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser",
//       value: {
//         id: "5a2e164b-4277-4c82-a905-4cbdbb10a99a",
//         name: "StrOutputParser",
//         type: "parser",
//         tags: [ "seq:step:3" ],
//         metadata: {},
//         start_time: "2024-01-08T20:55:53.553Z",
//         streamed_output_str: [],
//         final_output: undefined,
//         end_time: undefined
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "Lang" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: "Lang"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "Smith" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: "Smith"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " is" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " is"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " a" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " a"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " platform" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " platform"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " that" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " that"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " offers" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " offers"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " features" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " features"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " for" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " for"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " debugging" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " debugging"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "," } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ","
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " testing" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " testing"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "," } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ","
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " evaluating" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " evaluating"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "," } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ","
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " and" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " and"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " monitoring" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " monitoring"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " Language" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " Language"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " Learning" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " Learning"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " Model" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " Model"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " (" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " ("
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "LL" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: "LL"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "M" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: "M"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: ")" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ")"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " applications" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " applications"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "." } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: "."
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " It" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " It"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " provides" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " provides"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " visibility" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " visibility"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " into" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " into"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " model" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " model"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " inputs" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " inputs"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " and" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " and"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " outputs" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " outputs"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "," } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ","
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " allows" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " allows"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " for" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " for"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " the" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " the"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " creation" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " creation"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " of" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " of"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " datasets" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " datasets"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " from" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " from"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " existing" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " existing"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " logs" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " logs"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "," } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ","
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " and" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " and"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " helps" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " helps"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " with" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " with"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " tracing" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " tracing"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " and" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " and"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " evaluating" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " evaluating"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " complex" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " complex"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " agent" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " agent"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " prompt" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " prompt"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " chains" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " chains"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "." } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: "."
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " Lang" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " Lang"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "Smith" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: "Smith"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " aims" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " aims"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " to" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " to"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " be" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " be"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " a" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " a"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " unified" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " unified"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " platform" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " platform"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " for" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " for"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " these" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " these"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " tasks" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " tasks"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " and" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " and"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " offers" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " offers"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " a" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " a"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " range" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " range"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " of" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " of"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " tools" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " tools"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " to" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " to"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " assist" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " assist"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " developers" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " developers"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " in" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " in"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " building" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " building"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " and" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " and"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " deploying" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " deploying"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " L" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " L"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "LM" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: "LM"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " applications" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: " applications"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "." } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: "."
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/final_output",
//       value: { generations: [ [Array] ] }
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/end_time",
//       value: "2024-01-08T20:55:54.773Z"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/final_output",
//       value: {
//         output: "LangSmith is a platform that offers features for debugging, testing, evaluating, and monitoring Lang"... 365 more characters
//       }
//     },
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/end_time",
//       value: "2024-01-08T20:55:54.992Z"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/RunnableSequence/final_output",
//       value: {
//         output: "LangSmith is a platform that offers features for debugging, testing, evaluating, and monitoring Lang"... 365 more characters
//       }
//     },
//     {
//       op: "add",
//       path: "/logs/RunnableSequence/end_time",
//       value: "2024-01-08T20:55:55.094Z"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "replace",
//       path: "/final_output",
//       value: {
//         output: "LangSmith is a platform that offers features for debugging, testing, evaluating, and monitoring Lang"... 365 more characters
//       }
//     }
//   ]
// }

// %%
for await (const step of await retrievalChain.streamLog(
  {
    question,
  },
  {},
  {
    includeNames: ["Docs"]
  }
)) {
  console.log(step);
}
// Out:
// RunLogPatch {
//   ops: [
//     {
//       op: "replace",
//       path: "",
//       value: {
//         id: "dda1bfc6-a13d-4a1c-8735-ebae341a4959",
//         streamed_output: [],
//         final_output: undefined,
//         logs: {}
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "Lang" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "Smith" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " is" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " a" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " platform" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " that" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " offers" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " features" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " for" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " debugging" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "," } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " testing" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "," } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " evaluating" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "," } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " and" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " monitoring" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " Language" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " Learning" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " Models" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " (" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "LL" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "Ms" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: ")" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " applications" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "." } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " It" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " provides" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " visibility" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " into" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " model" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " inputs" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " and" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " outputs" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "," } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " allows" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " for" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " dataset" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " creation" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " and" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " testing" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "," } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " and" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " incorporates" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " user" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " feedback" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " to" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " improve" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " applications" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "." } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " It" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " also" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " offers" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " a" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " unified" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " platform" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " for" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " managing" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " L" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "LM" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " workflows" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " and" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " provides" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " tools" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " for" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " tracing" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " and" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " evaluating" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " complex" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " agent" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " prompt" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " chains" } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "." } ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "replace",
//       path: "/final_output",
//       value: {
//         output: "LangSmith is a platform that offers features for debugging, testing, evaluating, and monitoring Lang"... 328 more characters
//       }
//     }
//   ]
// }

// %% [markdown]
// ## Agents
//
// ### Stream Actions

// %%
import { pull } from "langchain/hub";
import { createOpenAIFunctionsAgent, AgentExecutor } from "langchain/agents";
import { ChatOpenAI } from "@langchain/openai";
import { TavilySearchResults } from "@langchain/community/tools/tavily_search";

// Get the prompt to use - you can modify this!
const prompt = await pull<ChatPromptTemplate>("hwchase17/openai-functions-agent");

const search = new TavilySearchResults();
const tools = [search];

const llm = new ChatOpenAI({
  modelName: "gpt-3.5-turbo",
  temperature: 0,
});

const agent = await createOpenAIFunctionsAgent({
  llm,
  tools,
  prompt,
});
const agentExecutor = new AgentExecutor({ agent, tools });

// %%
for await (const chunk of await agentExecutor.stream({
  input: "what is the weather in SF and then LA"
})) {
  console.log(chunk);
  console.log("---------")
}
// Out:
// {
//   intermediateSteps: [
//     {
//       action: {
//         tool: "tavily_search_results_json",
//         toolInput: { input: "weather in San Francisco" },
//         log: 'Invoking "tavily_search_results_json" with {\n' +
//           '  "input": "weather in San Francisco"\n' +
//           "}\n",
//         messageLog: [ [AIMessage] ]
//       },
//       observation: '[{"title":"Weather in San Francisco in January 2024","url":"https://world-weather.info/forecast/usa/'... 2004 more characters
//     }
//   ]
// }
// ---------
// {
//   intermediateSteps: [
//     {
//       action: {
//         tool: "tavily_search_results_json",
//         toolInput: { input: "weather in Los Angeles" },
//         log: 'Invoking "tavily_search_results_json" with {\n' +
//           '  "input": "weather in Los Angeles"\n' +
//           "}\n",
//         messageLog: [ [AIMessage] ]
//       },
//       observation: '[{"title":"Weather for Los Angeles | People°s Weather","url":"https://www.peoplesweather.com/weather'... 2355 more characters
//     }
//   ]
// }
// ---------
// {
//   output: "The weather in San Francisco today is around 9°C with mostly cloudy skies. The temperature in Los An"... 60 more characters
// }
// ---------

// %% [markdown]
// ### Stream Tokens

// %%
const llm = new ChatOpenAI({
  modelName: "gpt-3.5-turbo",
  temperature: 0,
  streaming: true,
});
const agent = await createOpenAIFunctionsAgent({
  llm,
  tools,
  prompt,
});
const agentExecutor = new AgentExecutor({ agent, tools });

// %%
for await (const step of await agentExecutor.streamLog(
  {
    input: "what is the weather in SF"
  },
  {},
  {
    includeNames: ["ChatOpenAI"]
  }
)) {
  console.log(step);
}
// Out:
// RunLogPatch {
//   ops: [
//     {
//       op: "replace",
//       path: "",
//       value: {
//         id: "4a080488-a0eb-4cd9-8351-25865ee8545f",
//         streamed_output: [],
//         final_output: undefined,
//         logs: {}
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI",
//       value: {
//         id: "ed87f596-e0d3-4a96-8a2d-ccfddac02530",
//         name: "ChatOpenAI",
//         type: "llm",
//         tags: [ "seq:step:3" ],
//         metadata: {},
//         start_time: "2024-01-08T20:56:13.050Z",
//         streamed_output_str: [],
//         final_output: undefined,
//         end_time: undefined
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/streamed_output_str/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/final_output",
//       value: {
//         generations: [ [Array] ],
//         llmOutput: { estimatedTokenUsage: [Object] }
//       }
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI/end_time",
//       value: "2024-01-08T20:56:14.493Z"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/streamed_output/-",
//       value: { intermediateSteps: [ [Object] ] }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2",
//       value: {
//         id: "08af70c0-cbc4-435c-b22c-9c0b03ec1317",
//         name: "ChatOpenAI",
//         type: "llm",
//         tags: [ "seq:step:3" ],
//         metadata: {},
//         start_time: "2024-01-08T20:56:19.175Z",
//         streamed_output_str: [],
//         final_output: undefined,
//         end_time: undefined
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: "The"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " weather"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " in"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " San"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " Francisco"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " is"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " currently"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " not"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " specified"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " in"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " the"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " search"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " results"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: "."
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " However"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: ","
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " you"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " can"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " check"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " the"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " weather"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " forecast"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " for"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " San"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " Francisco"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " on"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " various"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " websites"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " such"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " as"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " Al"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: "man"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: "ac"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: ".com"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: ","
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " Peoples"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: "Weather"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: ".com"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: ","
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " Yahoo"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " News"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: ","
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " Weather"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: "Tab"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: ".com"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: ","
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " or"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: " World"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: "-"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: "Weather"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: ".info"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: "."
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/streamed_output_str/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/final_output",
//       value: {
//         generations: [ [Array] ],
//         llmOutput: { estimatedTokenUsage: [Object] }
//       }
//     },
//     {
//       op: "add",
//       path: "/logs/ChatOpenAI:2/end_time",
//       value: "2024-01-08T20:56:20.355Z"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "replace",
//       path: "/final_output",
//       value: {
//         output: "The weather in San Francisco is currently not specified in the search results. However, you can chec"... 152 more characters
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/streamed_output/-",
//       value: {
//         output: "The weather in San Francisco is currently not specified in the search results. However, you can chec"... 152 more characters
//       }
//     }
//   ]
// }
